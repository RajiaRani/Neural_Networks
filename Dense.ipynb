# %% [markdown]
# 🔹 Case 1: Weights stored as (inputs × neurons)
# Shape: (inputs, neurons)
# Each column = weights for one neuron
#
# Convenient for coding (NNFS library uses this)
#
# Forward pass:  𝑍 = 𝑋.𝑊 + 𝑏
# Z=XW+b
#
# ✅ No transpose needed.

# %%
import numpy as np

# Take 2 inputs and 3 neurons
X = np.array([1, 2])
W = np.array([[0.2, 0.8, -0.5], [0.5, -0.9, 0.26]]) # shape (1,2) 1 sample, 2 features
B = np.array([2, 3, 0.5])

#Forward pss
Z = np.dot(X, W) + B
print("Final result:", Z)
# Out:
# Final result: [3.2  2.   0.52]

# %% [markdown]
# 🔹 Case 2: Weights stored as (neurons × inputs)
# 2. Neurons × Inputs (this new case)
# Shape: (neurons, inputs)
#
# Each row = weights for one neuron
#
# More common in textbooks
#
# Forward pass:
#
# 𝑍 = 𝑋 𝑊 𝑇 +𝑏
# Z= XWT +b
#
# 👉 Here we must transpose to align shapes.

# %%
X = np.array([1,2])
W = np.array([ [0.2, 0.5], [0.8, -0.9], [-0.5, 0.26]])
B = np.array([2, 3, 0.5])
Z = np.dot(X, W.T) + B
print(Z)
# Out:
# [3.2  2.   0.52]

# %%
#Dense layer
class Layer_dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))
    def forward(self, inputs):
        self.output = np.dot(inputs, self.weights) + self.biases
    X, y = spiral_data(samples=100, classes=3) 

dense1 = Layer_dense(2,3)
dense1.forward(X)
print(dense1.output[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Dense layer
# ----> 2 class Layer_dense:
#       3     def __init__(self, n_inputs, n_neurons):
#       4         self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
#
# Cell In[5], line 8, in Layer_dense()
#       6 def forward(self, inputs):
#       7     self.output = np.dot(inputs, self.weights) + self.biases
# ----> 8 X, y = spiral_data(samples=100, classes=3)
#
# NameError: name 'spiral_data' is not defined
