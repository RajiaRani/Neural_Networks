# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(4, input_shape=(3,5)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_8 (SimpleRNN)        │ (None, 4)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45 (180.00 B)
#  Trainable params: 45 (180.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 4)
# array([[-0.02820486, -0.60843766, -0.3909402 ,  0.5536293 ],
#        [ 0.2142247 , -0.63631135,  0.06214464, -0.4936754 ],
#        [-0.30662382,  0.77533877,  0.38447976, -0.28680098],
#        [ 0.00231498, -0.11242288, -0.12745279, -0.14875746],
#        [-0.24110132,  0.7930808 , -0.0057655 , -0.75764674]],
#       dtype=float32)

# %%
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (4, 4)
# array([[-0.5523977 , -0.03162464,  0.5288766 , -0.643542  ],
#        [ 0.562041  ,  0.3651965 , -0.24395753, -0.7008753 ],
#        [-0.45650658, -0.30676457, -0.79737556, -0.24837363],
#        [ 0.41299957, -0.87836605,  0.15800774, -0.1814884 ]],
#       dtype=float32)

# %%
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (4,)
# array([0., 0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (4, 1)
# array([[ 1.093622  ],
#        [-0.53466934],
#        [-0.4705249 ],
#        [-0.7161608 ]], dtype=float32)

# %%
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)
