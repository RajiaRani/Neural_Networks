# %%
import numpy as np
inputs = [ 1 , 2 , 3 , 2.5 ]
weights = [0.1, 0.02, 0.03, 0.01]
# weights = [
#     [ 0.2 , 0.8 ,- 0.5 , 1 ],
#     [ 0.5 , - 0.91 , 0.26 ,- 0.5 ],
#     [ - 0.26 , - 0.27 , 0.17 , 0.87 ]
#     ]
biases = 1

output = np.dot(inputs, weights) + biases
print(output)
# Out:
# 1.255

# %%
x = [0.1, 2.0, 0.4, 0.6]
w = [
    [ 0.2 , 0.8 ,- 0.5 , 1 ],
    [ 0.5 , - 0.91 , 0.26 ,- 0.5 ],
    [ - 0.26 , - 0.27 , 0.17 , 0.87 ],
    [ - 0.26 , - 0.27 , 0.17 , 0.87 ],
]
b = [0.1, 0.2, 0.1, 0.3]
output = np.dot(x,w) + b
print(output)
# Out:
# [ 0.86 -1.81  0.74  0.27]

# %%
x = [0.1, 2.0, 0.4, 0.6]
w = [
    [ 0.2 , 0.8 ,- 0.5 , 1 ],
    [ 0.5 , - 0.91 , 0.26 ,- 0.5 ],
    [ - 0.26 , - 0.27 , 0.17 , 0.87 ],
]
b = [0.1, 0.2, 0.1]
output = np.dot(x,np.array(w).T) + b
print(output)
# Out:
# [ 2.12  -1.766  0.124]
